# %%
# Dependencies and Setup
import pandas as pd


# Output File (CSV)
input_data_file = "assets/cities.csv"
output_data_file = "C:/Web-Design-Challenge/assets/cities.html"

# %%
# read in CSV file into dataframe
df = pd.read_csv("C:/Web-Design-Challenge/assets/cities.csv")

# %%
df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Hilo  19.7297 -155.0900     69.80        78           1
# 1           Mareeba -17.0000  145.4333     86.00        79          75
# 2    Cabo San Lucas  22.8909 -109.9124     61.00        68           0
# 3         Saskylakh  71.9167  114.0833    -25.15        85          99
# 4       Cross Lanes  38.4204  -81.7907     35.01        80          90
# ..              ...      ...       ...       ...       ...         ...
# 566      Porto Belo -27.1578  -48.5531     77.00        83           0
# 567       Liaozhong  41.5061  122.7242      8.60        28           0
# 568       Hay River  60.8156 -115.7999     15.80        85           0
# 569          Ossora  59.2353  163.0719     -7.28        82          58
# 570         Guanica  17.9716  -66.9080     70.00        76           0
#
#      Wind Speed Country        Date
# 0          6.91      US  1610090621
# 1          4.61      AU  1610090246
# ...

# %%
# write the file to HTML format
df.to_html(output_data_file)
